# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series, DataFrame

# %%
df1=pd.read_csv('tips.csv')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2 = df1.filter(["time","total_bill","tip"], axis=1)

# %%
df2.head()
# Out:
#      time  total_bill   tip
# 0  Dinner       16.99  1.01
# 1  Dinner       10.34  1.66
# 2  Dinner       21.01  3.50
# 3  Dinner       23.68  3.31
# 4  Dinner       24.59  3.61

# %%
plt.hist(df1['total_bill'],color='orange',bins=[10,15,25,30,50],edgecolor='black',rwidth=0.5)
plt.show()

# %%
df1['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
plt.bar(df1['day'].value_counts().index,df1['day'].value_counts().values)
# Out:
# <BarContainer object of 4 artists>

# %%
df1.groupby('day').mean()['total_bill'].plot(kind='bar')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10992\4108491144.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1.groupby('day').mean()['total_bill'].plot(kind='bar')

# %%
df1.groupby('sex').mean()['total_bill'].plot(kind='bar')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10992\482029829.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1.groupby('sex').mean()['total_bill'].plot(kind='bar')
# <Axes: xlabel='sex'>

# %%
sns.barplot(df1['day'].value_counts().index,df1['day'].value_counts().values)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.barplot(df1['day'].value_counts().index,df1['day'].value_counts().values)
#       2 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
df_iris=pd.read_csv('iris.csv')

# %%
df_iris.head()
# Out:
#    Unnamed: 0  sepal_width  petal_length  petal_width          species
# 0          82          2.7           3.9          1.2  Iris-versicolor
# 1          27          3.5           1.5          0.2      Iris-setosa
# 2           9          3.1           1.5          0.1      Iris-setosa
# 3          14          4.0           1.2          0.2      Iris-setosa
# 4          61          3.0           4.2          1.5  Iris-versicolor

# %%
sns.boxplot(x="species",y="petal_length",data=df_iris)
plt.show()

# %%
sns.FacetGrid(df_iris, hue ="species",height = 6).map(plt.scatter,'sepal_width','petal_width').add_legend()

# %%
df_iris.sepal_width.hist()
plt.title('Histogram of Age')
plt.xlabel('sepal_width')
plt.ylabel('Frequency')
#plt.savefig('hist_age')
# Out:
# Text(0, 0.5, 'Frequency')
